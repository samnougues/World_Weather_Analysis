# %%
# Import the dependencies.
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key
# %matplotlib inline
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=07b5a6e015052517c5d9f024eb712c81

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | koulamoutou
# Processing Record 3 of Set 1 | cabo san lucas
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | sakaiminato
# Processing Record 7 of Set 1 | umm lajj
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | manzanillo
# Processing Record 12 of Set 1 | medina del campo
# Processing Record 13 of Set 1 | bandarbeyla
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | kerema
# Processing Record 16 of Set 1 | te anau
# Processing Record 17 of Set 1 | touros
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | margate
# Processing Record 20 of Set 1 | saskylakh
# Processing Record 21 of Set 1 | lompoc
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | okitipupa
# Processing Record 24 of Set 1 | ladario
# Processing Record 25 of Set 1 | dicabisagan
# Processing Record 26 of Set 1 | nyurba
# Processing Record 27 of Set 1 | brae
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | eldikan
# City not found. Skipping...
# Processing Record 30 of Set 1 | ostrovnoy
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | iqaluit
# Processing Record 37 of Set 1 | sorong
# Processing Record 38 of Set 1 | svetlogorsk
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | deloraine
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | east london
# Processing Record 43 of Set 1 | voskresenskoye
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | victoria
# Processing Record 47 of Set 1 | san patricio
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | pisco
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | cerrito
# Processing Record 4 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 2 | bubaque
# Processing Record 6 of Set 2 | senanga
# Processing Record 7 of Set 2 | olga
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | vostok
# Processing Record 10 of Set 2 | georgetown
# Processing Record 11 of Set 2 | mount gambier
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | lanycsok
# Processing Record 15 of Set 2 | resistencia
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | bredasdorp
# Processing Record 18 of Set 2 | dunedin
# Processing Record 19 of Set 2 | qasigiannguit
# Processing Record 20 of Set 2 | acapulco
# Processing Record 21 of Set 2 | vanavara
# Processing Record 22 of Set 2 | nemuro
# Processing Record 23 of Set 2 | saint george
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | arkhangelsk
# Processing Record 26 of Set 2 | pacifica
# Processing Record 27 of Set 2 | cap malheureux
# Processing Record 28 of Set 2 | sur
# Processing Record 29 of Set 2 | invermere
# Processing Record 30 of Set 2 | rakhya
# City not found. Skipping...
# Processing Record 31 of Set 2 | kuching
# Processing Record 32 of Set 2 | dalnerechensk
# Processing Record 33 of Set 2 | guerrero negro
# Processing Record 34 of Set 2 | cidreira
# Processing Record 35 of Set 2 | busselton
# Processing Record 36 of Set 2 | fortuna
# Processing Record 37 of Set 2 | rawson
# Processing Record 38 of Set 2 | punta arenas
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | tingi
# Processing Record 41 of Set 2 | pevek
# Processing Record 42 of Set 2 | coahuayana
# Processing Record 43 of Set 2 | santa vitoria do palmar
# Processing Record 44 of Set 2 | iquique
# Processing Record 45 of Set 2 | tongliao
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | jatai
# Processing Record 48 of Set 2 | itacare
# Processing Record 49 of Set 2 | the valley
# Processing Record 50 of Set 2 | yomitan
# City not found. Skipping...
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | nouadhibou
# Processing Record 3 of Set 3 | vao
# Processing Record 4 of Set 3 | cape town
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | high level
# Processing Record 7 of Set 3 | cairo
# Processing Record 8 of Set 3 | george
# Processing Record 9 of Set 3 | ponta do sol
# Processing Record 10 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 3 | oksbol
# Processing Record 12 of Set 3 | fort nelson
# Processing Record 13 of Set 3 | batsfjord
# Processing Record 14 of Set 3 | poum
# Processing Record 15 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 3 | hasaki
# Processing Record 17 of Set 3 | gizo
# Processing Record 18 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | dalby
# Processing Record 21 of Set 3 | isangel
# Processing Record 22 of Set 3 | qaanaaq
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | bluff
# Processing Record 25 of Set 3 | nybro
# Processing Record 26 of Set 3 | acuna
# City not found. Skipping...
# Processing Record 27 of Set 3 | kruisfontein
# Processing Record 28 of Set 3 | hofn
# Processing Record 29 of Set 3 | raton
# Processing Record 30 of Set 3 | salalah
# Processing Record 31 of Set 3 | saint-philippe
# Processing Record 32 of Set 3 | castro
# Processing Record 33 of Set 3 | southampton
# Processing Record 34 of Set 3 | consett
# Processing Record 35 of Set 3 | tangping
# Processing Record 36 of Set 3 | haapiti
# Processing Record 37 of Set 3 | salekhard
# Processing Record 38 of Set 3 | balkhash
# Processing Record 39 of Set 3 | acajutla
# Processing Record 40 of Set 3 | asau
# Processing Record 41 of Set 3 | leshan
# Processing Record 42 of Set 3 | sampit
# Processing Record 43 of Set 3 | togur
# Processing Record 44 of Set 3 | barra do garcas
# Processing Record 45 of Set 3 | fort-shevchenko
# Processing Record 46 of Set 3 | honiara
# Processing Record 47 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 3 | karasjok
# Processing Record 49 of Set 3 | lahij
# Processing Record 50 of Set 3 | buala
# Processing Record 1 of Set 4 | chingirlau
# Processing Record 2 of Set 4 | hobart
# Processing Record 3 of Set 4 | constitucion
# Processing Record 4 of Set 4 | atar
# Processing Record 5 of Set 4 | birin
# Processing Record 6 of Set 4 | saysain
# Processing Record 7 of Set 4 | saldanha
# Processing Record 8 of Set 4 | tura
# Processing Record 9 of Set 4 | aklavik
# Processing Record 10 of Set 4 | sao caitano
# Processing Record 11 of Set 4 | alice springs
# Processing Record 12 of Set 4 | chifeng
# Processing Record 13 of Set 4 | del rio
# Processing Record 14 of Set 4 | kaitangata
# Processing Record 15 of Set 4 | kibungo
# Processing Record 16 of Set 4 | marquette
# Processing Record 17 of Set 4 | avera
# Processing Record 18 of Set 4 | gayeri
# Processing Record 19 of Set 4 | grand gaube
# Processing Record 20 of Set 4 | ranong
# Processing Record 21 of Set 4 | trelew
# Processing Record 22 of Set 4 | broken hill
# Processing Record 23 of Set 4 | jiroft
# City not found. Skipping...
# Processing Record 24 of Set 4 | emerald
# Processing Record 25 of Set 4 | nurota
# Processing Record 26 of Set 4 | lebu
# Processing Record 27 of Set 4 | brufut
# Processing Record 28 of Set 4 | kisangani
# Processing Record 29 of Set 4 | metaxades
# Processing Record 30 of Set 4 | porto novo
# Processing Record 31 of Set 4 | thompson
# Processing Record 32 of Set 4 | tuktoyaktuk
# Processing Record 33 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 34 of Set 4 | boguchany
# Processing Record 35 of Set 4 | moscow
# Processing Record 36 of Set 4 | mirosi
# Processing Record 37 of Set 4 | tautira
# Processing Record 38 of Set 4 | san carlos de bariloche
# Processing Record 39 of Set 4 | bethel
# Processing Record 40 of Set 4 | miyako
# Processing Record 41 of Set 4 | namibe
# Processing Record 42 of Set 4 | mujiayingzi
# Processing Record 43 of Set 4 | plavsk
# Processing Record 44 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 45 of Set 4 | shitanjing
# Processing Record 46 of Set 4 | talnakh
# Processing Record 47 of Set 4 | okhotsk
# Processing Record 48 of Set 4 | ust-nera
# Processing Record 49 of Set 4 | miles city
# Processing Record 50 of Set 4 | talcahuano
# Processing Record 1 of Set 5 | tazovskiy
# Processing Record 2 of Set 5 | batken
# Processing Record 3 of Set 5 | bambous virieux
# Processing Record 4 of Set 5 | klaksvik
# Processing Record 5 of Set 5 | charters towers
# Processing Record 6 of Set 5 | baruun-urt
# Processing Record 7 of Set 5 | cadiz
# Processing Record 8 of Set 5 | paks
# Processing Record 9 of Set 5 | sechura
# Processing Record 10 of Set 5 | sorland
# Processing Record 11 of Set 5 | kavieng
# Processing Record 12 of Set 5 | ji-parana
# City not found. Skipping...
# Processing Record 13 of Set 5 | moose factory
# Processing Record 14 of Set 5 | ponnampet
# Processing Record 15 of Set 5 | sumenep
# Processing Record 16 of Set 5 | vila franca do campo
# Processing Record 17 of Set 5 | balloszog
# Processing Record 18 of Set 5 | volno-nadezhdinskoye
# Processing Record 19 of Set 5 | narsaq
# Processing Record 20 of Set 5 | shimoda
# Processing Record 21 of Set 5 | ulaangom
# Processing Record 22 of Set 5 | asfi
# Processing Record 23 of Set 5 | honningsvag
# Processing Record 24 of Set 5 | mayo
# Processing Record 25 of Set 5 | neka
# Processing Record 26 of Set 5 | san quintin
# Processing Record 27 of Set 5 | humaita
# Processing Record 28 of Set 5 | qaqortoq
# Processing Record 29 of Set 5 | vila velha
# Processing Record 30 of Set 5 | inirida
# Processing Record 31 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 5 | luderitz
# Processing Record 33 of Set 5 | geraldton
# Processing Record 34 of Set 5 | leningradskiy
# Processing Record 35 of Set 5 | husavik
# Processing Record 36 of Set 5 | samarai
# Processing Record 37 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 38 of Set 5 | waitati
# Processing Record 39 of Set 5 | cherskiy
# Processing Record 40 of Set 5 | nuqui
# Processing Record 41 of Set 5 | cambridge
# Processing Record 42 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 5 | erzin
# Processing Record 44 of Set 5 | lagoa
# Processing Record 45 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 5 | tadine
# Processing Record 47 of Set 5 | diapaga
# Processing Record 48 of Set 5 | virginia beach
# Processing Record 49 of Set 5 | grindavik
# Processing Record 50 of Set 5 | denpasar
# Processing Record 1 of Set 6 | tuatapere
# Processing Record 2 of Set 6 | buin
# Processing Record 3 of Set 6 | areosa
# Processing Record 4 of Set 6 | buriti bravo
# Processing Record 5 of Set 6 | turukhansk
# Processing Record 6 of Set 6 | hangu
# Processing Record 7 of Set 6 | kihei
# Processing Record 8 of Set 6 | moshenskoye
# Processing Record 9 of Set 6 | wagar
# Processing Record 10 of Set 6 | biak
# Processing Record 11 of Set 6 | balti
# Processing Record 12 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 14 of Set 6 | sao joao da barra
# Processing Record 15 of Set 6 | sinnamary
# Processing Record 16 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 6 | tabuk
# Processing Record 18 of Set 6 | port elizabeth
# Processing Record 19 of Set 6 | tarakan
# Processing Record 20 of Set 6 | vardo
# Processing Record 21 of Set 6 | kailua
# Processing Record 22 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 6 | sosnogorsk
# Processing Record 24 of Set 6 | maceio
# Processing Record 25 of Set 6 | ushtobe
# Processing Record 26 of Set 6 | aldan
# Processing Record 27 of Set 6 | nandi
# Processing Record 28 of Set 6 | ketchikan
# Processing Record 29 of Set 6 | muros
# Processing Record 30 of Set 6 | whitehorse
# Processing Record 31 of Set 6 | luena
# Processing Record 32 of Set 6 | bombay
# Processing Record 33 of Set 6 | kutum
# Processing Record 34 of Set 6 | urumqi
# Processing Record 35 of Set 6 | airai
# Processing Record 36 of Set 6 | rio claro
# Processing Record 37 of Set 6 | gat
# Processing Record 38 of Set 6 | lorengau
# Processing Record 39 of Set 6 | pochutla
# Processing Record 40 of Set 6 | port hueneme
# Processing Record 41 of Set 6 | boyolangu
# Processing Record 42 of Set 6 | miranda
# Processing Record 43 of Set 6 | labuhan
# Processing Record 44 of Set 6 | isla mujeres
# Processing Record 45 of Set 6 | boyle
# Processing Record 46 of Set 6 | kudahuvadhoo
# Processing Record 47 of Set 6 | akureyri
# Processing Record 48 of Set 6 | soe
# Processing Record 49 of Set 6 | bondo
# Processing Record 50 of Set 6 | guiratinga
# Processing Record 1 of Set 7 | faya
# Processing Record 2 of Set 7 | tilichiki
# Processing Record 3 of Set 7 | srednekolymsk
# Processing Record 4 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 7 | neuchatel
# Processing Record 6 of Set 7 | bukama
# Processing Record 7 of Set 7 | hamilton
# Processing Record 8 of Set 7 | redcliffe
# Processing Record 9 of Set 7 | sioux lookout
# Processing Record 10 of Set 7 | loukhi
# Processing Record 11 of Set 7 | waingapu
# Processing Record 12 of Set 7 | derzhavinsk
# Processing Record 13 of Set 7 | yulara
# Processing Record 14 of Set 7 | kamenka
# Processing Record 15 of Set 7 | barrow
# Processing Record 16 of Set 7 | burica
# City not found. Skipping...
# Processing Record 17 of Set 7 | sitka
# Processing Record 18 of Set 7 | saint-louis
# Processing Record 19 of Set 7 | dmitriyevka
# Processing Record 20 of Set 7 | hanna
# Processing Record 21 of Set 7 | kashi
# Processing Record 22 of Set 7 | kaduy
# Processing Record 23 of Set 7 | amapa
# Processing Record 24 of Set 7 | souillac
# Processing Record 25 of Set 7 | dutse
# Processing Record 26 of Set 7 | faanui
# Processing Record 27 of Set 7 | olafsvik
# Processing Record 28 of Set 7 | sainte-maxime
# Processing Record 29 of Set 7 | igurusi
# Processing Record 30 of Set 7 | lysva
# Processing Record 31 of Set 7 | fare
# Processing Record 32 of Set 7 | bardiyah
# Processing Record 33 of Set 7 | verkhnyaya inta
# Processing Record 34 of Set 7 | codrington
# Processing Record 35 of Set 7 | port hardy
# Processing Record 36 of Set 7 | hambantota
# Processing Record 37 of Set 7 | provideniya
# Processing Record 38 of Set 7 | kosh-agach
# Processing Record 39 of Set 7 | requena
# Processing Record 40 of Set 7 | khatanga
# Processing Record 41 of Set 7 | adrar
# Processing Record 42 of Set 7 | havelock
# Processing Record 43 of Set 7 | minab
# Processing Record 44 of Set 7 | benicarlo
# Processing Record 45 of Set 7 | okha
# Processing Record 46 of Set 7 | quatre cocos
# Processing Record 47 of Set 7 | lubango
# Processing Record 48 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 49 of Set 7 | rabo de peixe
# Processing Record 50 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 1 of Set 8 | gurupa
# Processing Record 2 of Set 8 | port blair
# Processing Record 3 of Set 8 | torbat-e jam
# Processing Record 4 of Set 8 | bathurst
# Processing Record 5 of Set 8 | bluefield
# Processing Record 6 of Set 8 | evensk
# Processing Record 7 of Set 8 | saint-georges
# Processing Record 8 of Set 8 | havre-saint-pierre
# Processing Record 9 of Set 8 | cuiluan
# Processing Record 10 of Set 8 | paamiut
# Processing Record 11 of Set 8 | karratha
# Processing Record 12 of Set 8 | dingle
# Processing Record 13 of Set 8 | kahului
# Processing Record 14 of Set 8 | balkanabat
# Processing Record 15 of Set 8 | carauari
# Processing Record 16 of Set 8 | mudgee
# Processing Record 17 of Set 8 | bathsheba
# Processing Record 18 of Set 8 | jackson
# Processing Record 19 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 8 | chernyshevskiy
# Processing Record 21 of Set 8 | bumba
# Processing Record 22 of Set 8 | hervey bay
# Processing Record 23 of Set 8 | tambura
# Processing Record 24 of Set 8 | roswell
# Processing Record 25 of Set 8 | xuddur
# Processing Record 26 of Set 8 | itoman
# Processing Record 27 of Set 8 | mnogovershinnyy
# Processing Record 28 of Set 8 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 29 of Set 8 | wanning
# Processing Record 30 of Set 8 | kunszentmiklos
# Processing Record 31 of Set 8 | fairbanks
# Processing Record 32 of Set 8 | ambunti
# Processing Record 33 of Set 8 | katsuura
# Processing Record 34 of Set 8 | naze
# Processing Record 35 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 36 of Set 8 | kirakira
# Processing Record 37 of Set 8 | san ramon
# Processing Record 38 of Set 8 | broome
# Processing Record 39 of Set 8 | lata
# Processing Record 40 of Set 8 | kargil
# Processing Record 41 of Set 8 | pangnirtung
# Processing Record 42 of Set 8 | ulaanbaatar
# Processing Record 43 of Set 8 | dourbali
# Processing Record 44 of Set 8 | springfield
# Processing Record 45 of Set 8 | norrtalje
# Processing Record 46 of Set 8 | shenjiamen
# Processing Record 47 of Set 8 | ust-dzheguta
# Processing Record 48 of Set 8 | moindou
# Processing Record 49 of Set 8 | dzerzhinsk
# Processing Record 50 of Set 8 | knysna
# Processing Record 1 of Set 9 | pasighat
# Processing Record 2 of Set 9 | kloulklubed
# Processing Record 3 of Set 9 | dongsheng
# Processing Record 4 of Set 9 | tucuman
# Processing Record 5 of Set 9 | ratnagiri
# Processing Record 6 of Set 9 | rio gallegos
# Processing Record 7 of Set 9 | sembe
# Processing Record 8 of Set 9 | mapimi
# Processing Record 9 of Set 9 | waverley
# Processing Record 10 of Set 9 | rafaela
# Processing Record 11 of Set 9 | coralville
# Processing Record 12 of Set 9 | itarema
# Processing Record 13 of Set 9 | sao jose da coroa grande
# Processing Record 14 of Set 9 | myaundzha
# Processing Record 15 of Set 9 | arlit
# Processing Record 16 of Set 9 | paraopeba
# Processing Record 17 of Set 9 | manga
# Processing Record 18 of Set 9 | indiana
# Processing Record 19 of Set 9 | new milford
# Processing Record 20 of Set 9 | ashqelon
# Processing Record 21 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 9 | bundaberg
# Processing Record 23 of Set 9 | pinega
# Processing Record 24 of Set 9 | ejura
# Processing Record 25 of Set 9 | kokkola
# Processing Record 26 of Set 9 | salinopolis
# Processing Record 27 of Set 9 | sarakhs
# Processing Record 28 of Set 9 | paraiso
# Processing Record 29 of Set 9 | camacari
# Processing Record 30 of Set 9 | kavaratti
# Processing Record 31 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 9 | yar-sale
# Processing Record 33 of Set 9 | palmer
# Processing Record 34 of Set 9 | gazli
# Processing Record 35 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 9 | hecun
# Processing Record 37 of Set 9 | alamosa
# Processing Record 38 of Set 9 | neiafu
# Processing Record 39 of Set 9 | pimentel
# Processing Record 40 of Set 9 | severo-yeniseyskiy
# Processing Record 41 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 42 of Set 9 | port lincoln
# Processing Record 43 of Set 9 | japura
# Processing Record 44 of Set 9 | muriwai beach
# Processing Record 45 of Set 9 | manggar
# Processing Record 46 of Set 9 | san cristobal
# Processing Record 47 of Set 9 | vangaindrano
# Processing Record 48 of Set 9 | saint-quentin
# Processing Record 49 of Set 9 | clyde river
# Processing Record 50 of Set 9 | comodoro rivadavia
# Processing Record 1 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 10 | ternate
# Processing Record 3 of Set 10 | nelson bay
# Processing Record 4 of Set 10 | goderich
# Processing Record 5 of Set 10 | smoky lake
# Processing Record 6 of Set 10 | ubinskoye
# Processing Record 7 of Set 10 | keshan
# City not found. Skipping...
# Processing Record 8 of Set 10 | san fernando
# Processing Record 9 of Set 10 | novoplatnirovskaya
# Processing Record 10 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 11 of Set 10 | carbonia
# Processing Record 12 of Set 10 | ust-kuyga
# Processing Record 13 of Set 10 | argayash
# Processing Record 14 of Set 10 | manokwari
# Processing Record 15 of Set 10 | milas
# Processing Record 16 of Set 10 | raudeberg
# Processing Record 17 of Set 10 | nome
# Processing Record 18 of Set 10 | lasa
# Processing Record 19 of Set 10 | dubbo
# Processing Record 20 of Set 10 | chara
# Processing Record 21 of Set 10 | esmeraldas
# Processing Record 22 of Set 10 | aanekoski
# Processing Record 23 of Set 10 | alofi
# Processing Record 24 of Set 10 | colac
# Processing Record 25 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 26 of Set 10 | bilibino
# Processing Record 27 of Set 10 | nalut
# Processing Record 28 of Set 10 | iquitos
# Processing Record 29 of Set 10 | shache
# Processing Record 30 of Set 10 | san juan
# Processing Record 31 of Set 10 | olinda
# Processing Record 32 of Set 10 | mount isa
# Processing Record 33 of Set 10 | west hartford
# Processing Record 34 of Set 10 | walvis bay
# Processing Record 35 of Set 10 | qianan
# Processing Record 36 of Set 10 | puerto baquerizo moreno
# Processing Record 37 of Set 10 | sigli
# Processing Record 38 of Set 10 | beringovskiy
# Processing Record 39 of Set 10 | port-cartier
# Processing Record 40 of Set 10 | puerto narino
# Processing Record 41 of Set 10 | ulladulla
# Processing Record 42 of Set 10 | gelemso
# Processing Record 43 of Set 10 | channel-port aux basques
# Processing Record 44 of Set 10 | mbalmayo
# Processing Record 45 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 10 | mar del plata
# Processing Record 47 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 10 | stralsund
# Processing Record 49 of Set 10 | vilhena
# Processing Record 50 of Set 10 | doka
# Processing Record 1 of Set 11 | nishihara
# Processing Record 2 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 11 | tessalit
# Processing Record 4 of Set 11 | vestmannaeyjar
# Processing Record 5 of Set 11 | pryazha
# Processing Record 6 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 11 | tanete
# Processing Record 8 of Set 11 | chunskiy
# Processing Record 9 of Set 11 | hinton
# Processing Record 10 of Set 11 | batagay-alyta
# Processing Record 11 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 12 of Set 11 | kalmunai
# Processing Record 13 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 11 | lokachi
# Processing Record 15 of Set 11 | la ronge
# Processing Record 16 of Set 11 | newcastle
# Processing Record 17 of Set 11 | monteagudo
# Processing Record 18 of Set 11 | sept-iles
# Processing Record 19 of Set 11 | varlamovo
# Processing Record 20 of Set 11 | general pico
# Processing Record 21 of Set 11 | chuy
# Processing Record 22 of Set 11 | pecos
# Processing Record 23 of Set 11 | uyskoye
# Processing Record 24 of Set 11 | eyl
# Processing Record 25 of Set 11 | port augusta
# Processing Record 26 of Set 11 | torbay
# Processing Record 27 of Set 11 | bonthe
# Processing Record 28 of Set 11 | miraflores
# Processing Record 29 of Set 11 | cazaje
# City not found. Skipping...
# Processing Record 30 of Set 11 | maputo
# Processing Record 31 of Set 11 | awjilah
# Processing Record 32 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 11 | north bend
# Processing Record 34 of Set 11 | kuloy
# Processing Record 35 of Set 11 | linkuva
# Processing Record 36 of Set 11 | puerto del rosario
# Processing Record 37 of Set 11 | cabedelo
# Processing Record 38 of Set 11 | saint anthony
# Processing Record 39 of Set 11 | xining
# Processing Record 40 of Set 11 | alta
# Processing Record 41 of Set 11 | spiridonovka
# Processing Record 42 of Set 11 | jeremie
# Processing Record 43 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 11 | ancud
# Processing Record 45 of Set 11 | jinzhou
# Processing Record 46 of Set 11 | san jose
# Processing Record 47 of Set 11 | chicama
# Processing Record 48 of Set 11 | baghdad
# Processing Record 49 of Set 11 | harper
# Processing Record 50 of Set 11 | norilsk
# Processing Record 1 of Set 12 | rajgarh
# Processing Record 2 of Set 12 | vastervik
# City not found. Skipping...
# Processing Record 3 of Set 12 | lebyazhye
# Processing Record 4 of Set 12 | mathbaria
# Processing Record 5 of Set 12 | haines junction
# Processing Record 6 of Set 12 | namli
# Processing Record 7 of Set 12 | arkhangelos
# City not found. Skipping...
# Processing Record 8 of Set 12 | marzuq
# Processing Record 9 of Set 12 | boende
# Processing Record 10 of Set 12 | zenzeli
# Processing Record 11 of Set 12 | moron
# Processing Record 12 of Set 12 | falaleu
# City not found. Skipping...
# Processing Record 13 of Set 12 | christchurch
# Processing Record 14 of Set 12 | flinders
# Processing Record 15 of Set 12 | pastavy
# Processing Record 16 of Set 12 | sindor
# Processing Record 17 of Set 12 | methoni
# Processing Record 18 of Set 12 | deputatskiy
# Processing Record 19 of Set 12 | sarlat-la-caneda
# Processing Record 20 of Set 12 | ouallam
# Processing Record 21 of Set 12 | higuey
# City not found. Skipping...
# Processing Record 22 of Set 12 | baykit
# Processing Record 23 of Set 12 | atbasar
# Processing Record 24 of Set 12 | kosa
# Processing Record 25 of Set 12 | aleksandrovskoye
# Processing Record 26 of Set 12 | el alto
# Processing Record 27 of Set 12 | mamou
# Processing Record 28 of Set 12 | laguna
# Processing Record 29 of Set 12 | sakakah
# Processing Record 30 of Set 12 | rongcheng
# Processing Record 31 of Set 12 | saint-francois
# Processing Record 32 of Set 12 | mirnyy
# Processing Record 33 of Set 12 | jardim
# Processing Record 34 of Set 12 | lenki
# City not found. Skipping...
# Processing Record 35 of Set 12 | yanji
# Processing Record 36 of Set 12 | neuquen
# Processing Record 37 of Set 12 | krasnogorskoye
# Processing Record 38 of Set 12 | sao filipe
# Processing Record 39 of Set 12 | mangrol
# Processing Record 40 of Set 12 | henties bay
# Processing Record 41 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 42 of Set 12 | puerto colombia
# Processing Record 43 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 44 of Set 12 | zyryanka
# Processing Record 45 of Set 12 | durant
# Processing Record 46 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 47 of Set 12 | mehran
# Processing Record 48 of Set 12 | karema
# Processing Record 49 of Set 12 | yatou
# Processing Record 50 of Set 12 | baiyin
# Processing Record 1 of Set 13 | kaspiyskiy
# Processing Record 2 of Set 13 | vestbygda
# City not found. Skipping...
# Processing Record 3 of Set 13 | sisimiut
# Processing Record 4 of Set 13 | severo-kurilsk
# Processing Record 5 of Set 13 | semirom
# Processing Record 6 of Set 13 | aykhal
# Processing Record 7 of Set 13 | palpa
# Processing Record 8 of Set 13 | ballina
# Processing Record 9 of Set 13 | swan river
# Processing Record 10 of Set 13 | beyneu
# Processing Record 11 of Set 13 | barcelos
# Processing Record 12 of Set 13 | dilla
# Processing Record 13 of Set 13 | nhulunbuy
# Processing Record 14 of Set 13 | impfondo
# Processing Record 15 of Set 13 | bereda
# Processing Record 16 of Set 13 | sao borja
# Processing Record 17 of Set 13 | rudbar
# Processing Record 18 of Set 13 | benguela
# Processing Record 19 of Set 13 | aasiaat
# Processing Record 20 of Set 13 | port-gentil
# Processing Record 21 of Set 13 | roald
# Processing Record 22 of Set 13 | visnes
# Processing Record 23 of Set 13 | antsohihy
# Processing Record 24 of Set 13 | yarega
# Processing Record 25 of Set 13 | gornopravdinsk
# Processing Record 26 of Set 13 | rubizhne
# Processing Record 27 of Set 13 | oda
# Processing Record 28 of Set 13 | langham
# Processing Record 29 of Set 13 | gobabis
# Processing Record 30 of Set 13 | viedma
# Processing Record 31 of Set 13 | maku
# Processing Record 32 of Set 13 | camocim
# Processing Record 33 of Set 13 | san-pedro
# Processing Record 34 of Set 13 | riviere-au-renard
# Processing Record 35 of Set 13 | sao francisco
# Processing Record 36 of Set 13 | sabha
# Processing Record 37 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 38 of Set 13 | borovoy
# Processing Record 39 of Set 13 | chimbote
# Processing Record 40 of Set 13 | buraydah
# Processing Record 41 of Set 13 | lakatoro
# Processing Record 42 of Set 13 | matagami
# Processing Record 43 of Set 13 | mocuba
# Processing Record 44 of Set 13 | liwale
# Processing Record 45 of Set 13 | chelno-vershiny
# Processing Record 46 of Set 13 | nizhnevartovsk
# Processing Record 47 of Set 13 | espanola
# Processing Record 48 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 13 | lyngseidet
# Processing Record 50 of Set 13 | noormarkku
# Processing Record 1 of Set 14 | pospelikha
# Processing Record 2 of Set 14 | santa maria del oro
# Processing Record 3 of Set 14 | ilulissat
# Processing Record 4 of Set 14 | manica
# Processing Record 5 of Set 14 | sitangkai
# Processing Record 6 of Set 14 | non thai
# Processing Record 7 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 14 | khandyga
# Processing Record 9 of Set 14 | andra
# Processing Record 10 of Set 14 | muzquiz
# City not found. Skipping...
# Processing Record 11 of Set 14 | sangar
# Processing Record 12 of Set 14 | zhuanghe
# Processing Record 13 of Set 14 | safford
# Processing Record 14 of Set 14 | kenosha
# Processing Record 15 of Set 14 | lagos
# Processing Record 16 of Set 14 | karoi
# Processing Record 17 of Set 14 | bambanglipuro
# Processing Record 18 of Set 14 | edd
# Processing Record 19 of Set 14 | tokmak
# Processing Record 20 of Set 14 | san marcos
# Processing Record 21 of Set 14 | bridlington
# Processing Record 22 of Set 14 | cravo norte
# Processing Record 23 of Set 14 | thinadhoo
# Processing Record 24 of Set 14 | teya
# Processing Record 25 of Set 14 | uk
# City not found. Skipping...
# Processing Record 26 of Set 14 | grootfontein
# Processing Record 27 of Set 14 | malakal
# Processing Record 28 of Set 14 | zambezi
# Processing Record 29 of Set 14 | saint-augustin
# Processing Record 30 of Set 14 | cockburn town
# Processing Record 31 of Set 14 | beloha
# Processing Record 32 of Set 14 | balsas
# Processing Record 33 of Set 14 | pacific grove
# Processing Record 34 of Set 14 | astana
# Processing Record 35 of Set 14 | humberto de campos
# Processing Record 36 of Set 14 | udachnyy
# Processing Record 37 of Set 14 | yazykovo
# Processing Record 38 of Set 14 | otradnoye
# Processing Record 39 of Set 14 | paragominas
# Processing Record 40 of Set 14 | kaeo
# Processing Record 41 of Set 14 | mungwi
# Processing Record 42 of Set 14 | isiro
# Processing Record 43 of Set 14 | komsomolskiy
# Processing Record 44 of Set 14 | erenhot
# Processing Record 45 of Set 14 | svecha
# Processing Record 46 of Set 14 | namatanai
# Processing Record 47 of Set 14 | carutapera
# Processing Record 48 of Set 14 | pajan
# Processing Record 49 of Set 14 | caravelas
# Processing Record 50 of Set 14 | ampanihy
# Processing Record 1 of Set 15 | todos santos
# Processing Record 2 of Set 15 | balykshi
# Processing Record 3 of Set 15 | muyezerskiy
# Processing Record 4 of Set 15 | say
# Processing Record 5 of Set 15 | vikhorevka
# Processing Record 6 of Set 15 | yajalon
# Processing Record 7 of Set 15 | bandarban
# Processing Record 8 of Set 15 | nabire
# Processing Record 9 of Set 15 | kaduqli
# Processing Record 10 of Set 15 | bagula
# Processing Record 11 of Set 15 | gorontalo
# Processing Record 12 of Set 15 | terra santa
# Processing Record 13 of Set 15 | bicas
# Processing Record 14 of Set 15 | ajdabiya
# Processing Record 15 of Set 15 | kongsberg
# Processing Record 16 of Set 15 | pula
# Processing Record 17 of Set 15 | abu kamal
# Processing Record 18 of Set 15 | eirunepe
# Processing Record 19 of Set 15 | korla
# Processing Record 20 of Set 15 | melbu
# Processing Record 21 of Set 15 | irece
# Processing Record 22 of Set 15 | kui buri
# Processing Record 23 of Set 15 | hovd
# Processing Record 24 of Set 15 | cardston
# Processing Record 25 of Set 15 | matay
# Processing Record 26 of Set 15 | newport
# Processing Record 27 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 15 | seybaplaya
# Processing Record 29 of Set 15 | baft
# Processing Record 30 of Set 15 | pitimbu
# Processing Record 31 of Set 15 | turiacu
# Processing Record 32 of Set 15 | goma
# Processing Record 33 of Set 15 | portland
# Processing Record 34 of Set 15 | vigrestad
# Processing Record 35 of Set 15 | phalodi
# Processing Record 36 of Set 15 | quezon
# Processing Record 37 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 15 | shihezi
# Processing Record 39 of Set 15 | koutsouras
# Processing Record 40 of Set 15 | alta floresta
# Processing Record 41 of Set 15 | quesnel
# Processing Record 42 of Set 15 | englewood
# Processing Record 43 of Set 15 | great bend
# Processing Record 44 of Set 15 | albanel
# Processing Record 45 of Set 15 | muriae
# Processing Record 46 of Set 15 | marsh harbour
# Processing Record 47 of Set 15 | kemijarvi
# Processing Record 48 of Set 15 | tanshui
# City not found. Skipping...
# Processing Record 49 of Set 15 | ratholo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
cities_data_df = pd.DataFrame(city_data)
cities_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0         Ushuaia -54.8000  -68.3000     38.86          light rain        93
# 1     Koulamoutou  -1.1303   12.4736     71.11          light rain       100
# 2  Cabo San Lucas  22.8909 -109.9124     76.51    scattered clouds        76
# 3          Albany  42.6001  -73.9662     57.72     overcast clouds        79
# 4     Port Alfred -33.5906   26.8910     56.17       broken clouds        95
# 5     Sakaiminato  35.5500  133.2333     58.98       broken clouds        88
# 6        Umm Lajj  25.0213   37.2685     77.32       broken clouds        61
# 7           Tiksi  71.6872  128.8694     -0.87       broken clouds        98
# 8         Mataura -46.1927  168.8643     73.71     overcast clouds        38
# 9      Manzanillo  20.3433  -77.1167     76.35    scattered clouds        76
#
#    Cloudiness  Wind Speed Country
# 0          75       17.27      AR
# 1         100        0.58      GA
# 2          30        3.00      MX
# 3         100        2.95      US
# 4          84       10.89      ZA
# 5          75        1.14      JP
# 6          67        8.34      SA
# 7          66        7.43      RU
# 8         100        5.48      NZ
# 9          30        3.58      CU

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
cities_data_df.to_csv(output_data_file, index_label="City_ID")
